# %%
#variables
name = "Krishna"
age = 19
pi = 3.14
print(name)
print(name,age)
print("My name is :" , name)
print("My age is : ",age)
# Out:
# Krishna
# Krishna 19
# My name is : Krishna
# My age is :  19

# %%
# checking for a boolean in datatypes
num = 5
isPrime = True 
print(type(isPrime))
# Out:
# <class 'bool'>

# %%
#operators
#arithmetic operator 
a = 10
b = 5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
# Out:
# 15
# 5
# 50
# 2.0
# 0
# 100000

# %%
#relational operators >,<,>=,<=,==,!=
a = 10
b = 5
print(a<b)
print(a>b)
print(5>8)
# Out:
# False
# True
# False

# %%
#assignment operator =,+=
a = 10
a=a+5 #15 / a+=5
print(a)
a = a/5 #a/=5
a=a*5 #a*=5
# Out:
# 15

# %%
#type conversion
a = 10
b = 5
print(a/5)
print(type(a/5))
# Out:
# 2.0
# <class 'float'>

# %%
ans1 = int(5+10.0) #castify
ans2 = 5+10.0 #conversion
print(ans1,type(ans1))
print(ans2,type(ans2))
# Out:
# 15 <class 'int'>
# 15.0 <class 'float'>

# %%
val = bool(10)
print(val,type(val))
# Out:
# True <class 'bool'>

# %%
#user input
a = input("enter value of a: ")
print(a)
username = input("enter your name: ")
print("Welcome",username)
# Out:
# enter value of a:  10
# 10
# enter your name:  krishna
# Welcome krishna

# %%
#sum of 2 number
a = input("enter a: ")
b = input("enter b: ")
sum = a+b
print(sum)
# Out:
# enter a:  10
# enter b:  5
# 105

# %%
#sum of 2 number
a = int(input("enter a: "))
b = int(input("enter b: "))
sum = a+b
print(sum)
# Out:
# enter a:  10
# enter b:  5
# 15

# %%
#print average(WAP to print average of 2 numbers)
a=float(input("enter first number: "))
b=float(input("enter second numbers: "))
avg = (a+b)/2
print("avg of 2 nums = ",avg)
# Out:
# enter first number:  10
# enter second numbers:  6
# avg of 2 nums =  8.0
