# %%
word = "python"
print(len(word))
# Out:
# 6

# %%
#join two strings
word1 = "I love"
word2 = "python"
#concatenate
print(word1 + word2)
print(word1 +" "+word2)
# Out:
# I lovepython
# I love python

# %%
word = "python"
for ch in word:
    print(ch)
# Out:
# p
# y
# t
# h
# o
# n

# %%
#string formating
a = 5
b = 10
sum =  a+b
print("sum is {}".format(sum))
# Out:
# sum is 15

# %%
#slicing
word = "I study from Apnacollage"
print(word[13 : len(word)])
# Out:
# Apnacollage

# %%
#lists: mutable sequence of values
marks1 = 99
marks2 = 89
marks3 = 100
marks4 = 65
marks5 = 92
marks = [99,89,100,65,92]
print(marks[1])
print(len(marks))
# Out:
# 89
# 5

# %%
#slicing in list 
marks = [99,89,100,65,92,"abc",100.99]
print(marks[5:len(marks)])
# Out:
# ['abc', 100.99]

# %%
#negative indexing
marks = [99,89,100,65,92,"abc",100.99]
print(marks[-5:-2])
# Out:
# [100, 65, 92]

# %%
#methods on the list 
nums = [1,2,3]
nums.append(4)
print(nums)
# Out:
# [1, 2, 3, 4]

# %%
nums = [1,2,3]
nums.append(4)
print(nums)
nums.insert(2,10)
print(nums)
# Out:
# [1, 2, 3, 4]
# [1, 2, 10, 3, 4]

# %%
nums = [1, 2, 10, 3, 4]
nums.sort()
print(nums)
# Out:
# [1, 2, 3, 4, 10]

# %%
nums = [1, 2, 10, 3, 4]
nums.reverse()
print(nums)
# Out:
# [4, 3, 10, 2, 1]

# %%
#lists with loops
nums = [1, 2, 10, 3, 4]
x = 10
idx = 0

for value in nums:
    if(value==x):
        print(" x found at idx = {idx)")
        break
    idx +=1
# Out:
#  x found at idx = {idx)

# %%
#tuple : immutable sequence of values
tup = (1,2,3,4,5)
print(tup)
print(type(tup))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %%
tup = (1,2,3,4,5)
print(tup[:])
# Out:
# (1, 2, 3, 4, 5)

# %%
#t.index(val) = returns 1st occurence idx
tup = (1,2,2,3,2,4)
print(tup.index(2))
# Out:
# 1

# %%
# t.count(value) = count total occurence
tup = (1,2,2,3,2,4)
print(tup.count(2))
# Out:
# 3

# %%
#dictionart = key : value pair
info = {
    "name" : "shradha"
    "cgpa": 9.2
    "subjects" : ["math","science"]}
print(type(info))
# Out:
#   Cell In[46], line 4
#     "cgpa": nine
#           ^
# SyntaxError: invalid syntax

# %%
#sets : collection of unique elements
s = {1,2,2,2,3}
print(type(s))
print(len(s))
# Out:
# <class 'set'>
# 3

# %%
s1 = {1,2,3,4,5}
s2 = {4,5,8,9,10}
print(s1.union(s2))
print(s1.intersection(s2))
# Out:
# {1, 2, 3, 4, 5, 8, 9, 10}
# {4, 5}
