# %%
age = int(input("enter age : "))
if age >= 18:
     print ("you can vote")
     print("you can drive")
else
     print("you cant vote")
# Out:
#   Cell In[7], line 5
#     else
#         ^
# SyntaxError: expected ':'

# %%
color = input("enter color: ")
if color =="red":
  print("stop")
elif color =="green":
  print("go")
elif color == "yellow":
  print("look")
else: print("wrong color for traffic lights")
# Out:
# enter color:  red
# stop

# %%
age = int(input("enter your age: "))
if (age < 13):
          print ("you are a child")
elif(age>=13 and age<18):
          print("you are a teenager")
else:
          print("you are adult")
# Out:
# enter your age:  15
# you are a teenager

# %%
username = input("enter username:")
password = input("enter password:")
if (username=="admin" and password == "pass"):
    print("login succesful")
elif(username != "admin"):
    print("wrong password")
else:
    print("wrong password")
# Out:
# enter username: admin
# enter password: pass
# login succesful

# %%
#print any no is odd or even
n = int(input("enter num: "))
if(n%2 ==0):
        print("even")
else:
        print("odd")
# Out:
# enter num:  5
# odd

# %%
#Nesting
username = input("enter username:")
password = input("enter password:")
if (username=="admin" and password == "pass"):
    print("login succesful")
else:
 if(username != "admin"):
    print("wrong username")
 else:
    print("wrong password")
# Out:
# enter username: admin
# enter password: 123
# wrong password

# %%
#match case
color = input("enter color: ")
match color:
    case"green":
        print("go")
    case "yellow":
        print("look")
    case "red":
        print("stop")
# Out:
# enter color:  red
# stop
