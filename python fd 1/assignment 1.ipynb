# %%
#Q1 Write a program that asks the user for their name and age, then prints a sentence like (Hello krishna, you are 21 years old)
username = input("enter your name:")
age = input("enter your age:")
print("Hello",username,"you are ",age,"year old")
# Out:
# enter your name: krishna
# enter your age: 19
# Hello krishna you are  19 year old

# %%
#Q2Take two numbers as input from the user and print their sum,difference,product and quotient
a= int(input("enter the first number: "))
b= int(input("enter the second number: "))
sum = a+b
difference =a-b
product =a*b
quotient = a/b
print(sum)
print(difference)
print(product)
print(quotient)
# Out:
# enter the first number:  10
# enter the second number:  5
# 15
# 5
# 50
# 2.0

# %%
#Q3Ask the user to enter two integers and one float. Convert them all to floats and print their average
a = int(input("Enter a : "))
b = float(input("Enter b : "))
c = float(input("Enter c : "))
average = (float(a)+float(b)+c)/3
print("Average: ",average)
# Out:
# Enter a :  10
# Enter b :  20
# Enter c :  32.8
# Average:  20.933333333333334

# %%
#Q4The user enters a string containing a number (e.g.,"45" ). Convert it to  an integer, a float, a string again Print all three values with their types

# %%
#Q6Write a program to swap values of two numbers entered by the user
a = input("Enter first number: ")
b = input("Enter second number: ")
a,b = b,a
print("After swapping:")
print("a=",a)
print("b=",b)
# Out:
# Enter first number:  10
# Enter second number:  5
# After swapping:
# a= 5
# b= 10

# %%
#Q7:Ask the user for a temperature in Celsius (string input). Convert it to float ,then calculate and print temperature in Fahrenheit
celcius = input("Enter the temprature in celcius :")
celcius = float(celcius)
fahrenheit = (celsius*9/5)+32  
print("Temprature is fahrenheit = ",fahrentiet)
# Out:
# Enter the temprature in celcius : 32
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 #Q7:Ask the user for a temperature in Celsius (string input). Convert it to float ,then calculate and print temperature in Fahrenheit
#       2 celcius = input("Enter the temprature in celcius :")
#       3 celcius = float(celcius)
# ----> 4 fahrenheit = (celsius*9/5)+32
#       5 print("Temprature is fahrenheit = ",fahrentiet)
#
# NameError: name 'celsius' is not defined
